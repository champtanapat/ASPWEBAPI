# %% [markdown]
# <a href="https://colab.research.google.com/github/champtanapat/ASPWEBAPI/blob/master/AI_week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #BFS Breadth First Search

# %% [markdown]
# ![Screenshot 2566-08-18 at 19.52.32.png](data:image/png;base64,...)

# %%
graph = {
  '5' : ['3','7'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : [],
  '4' : ['8'],
  '8' : []
}

visited = [] # List for visited nodes.
queue = []     #Initialize a queue

def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0)
    print (m, end = " ")

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph, '5')    # function calling
# Out:
# Following is the Breadth-First Search
# 5 3 7 2 4 8

# %% [markdown]
# # DFS Depth First Search

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Using a Python dictionary to act as an adjacency list
graph = {
  '5' : ['3','7'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : [],
  '4' : ['8'],
  '8' : []
}

visited = set() # Set to keep track of visited nodes of graph.

def dfs(visited, graph, node):  #function for dfs
    if node not in visited:
        print (node)
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)

# Driver Code
print("Following is the Depth-First Search")
dfs(visited, graph, '5')
# Out:
# Following is the Depth-First Search
# 5
# 3
# 2
# 4
# 8
# 7

# %% [markdown]
# ![assignment AI week 4_1 (1).png](data:image/png;base64,...)

# %% [markdown]
# # ข้อที่ 1 Graph To Tree

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ข้อ 2 DFS, BSF, UCS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![assignment AI week 4_1 (5).png](data:image/png;base64,...)![assignment AI week 4_1 (4).png](data:image/png;base64,...)![assignment AI week 4_1 (3).png](data:image/png;base64,...)

# %% [markdown]
# # ข้อ 3 ข้อดี Advantages ข้อเสีย Disadvantages

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![assignment AI week 4_1 (7).png](data:image/png;base64,...)![assignment AI week 4_1 (6).png](data:image/png;base64,...)
